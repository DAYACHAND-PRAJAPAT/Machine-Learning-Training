# %%
# Data visualisation -> graphs and plot
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as ans

# %%
arr1 = np.random.randint(2000,50000,100)
arr1
# Out:
# array([30838, 25640, 16219, 25500, 40924,  2196, 36679, 27876, 20022,
#        35964, 40654, 11752, 30912, 12818, 21464, 47860, 44324, 49946,
#        10970,  8846, 30427, 22032, 18109, 18857, 39275, 29608, 23072,
#        44453, 21354, 41336, 25251,  6119,  9065, 10751, 24722, 42364,
#        14114, 14812, 23298,  3925, 37423, 34024, 22911,  5521,  6047,
#        16149, 29444, 10065, 48973, 17544, 28367, 12243, 29700, 37197,
#        23360, 37425, 30914, 15783, 10363, 46409, 36501, 15650, 41457,
#        25439, 12640, 14144,  9947, 11849,  9088,  8242, 34053, 14572,
#        42526, 46886, 36803, 39969, 10661, 48556, 28473, 24980,  6390,
#        39992, 26979, 17074, 49778, 43608, 23298, 37927, 22819,  3443,
#        35873, 30899, 30161, 15051, 20979, 44452,  4266,  7211,  3235,
#        30242])

# %%
plt.plot(arr1)
plt.show()

# %%
arr1.sort()
plt.plot(arr1)

# %%
x = [1,2,3,4,5,6]
y = [1,4,9,16,25,36]
plt.plot(x,y)
plt.plot(x,y, marker = 'H',
            ms = 15,
            mfc = "skyblue",
            mec = "black",
            color = 'red',
            linewidth = '3',
            ls = 'dashed',
            alpha = 0.5)
plt.xlabel('X - Axis')
plt.ylabel('Y - Axis')
# Out:
# Text(0, 0.5, 'Y - Axis')

# %%
## scatter plot
x = [1,2,3,4,5,6]
y = [1,4,9,16,25,36]
plt.scatter(x,y, marker='*')

# %%
df = pd.read_csv('Used_Bikes.csv')
df.head()

# %%
plt.show()
plt.scatter(df["price"],df['kms_driven'])

# %%
## bar plot
x = ["Mp","Up","Rj","Mh"]
y = [3000,5000,4000,4500]
colours = ["red","green","blue","yellow"]
plt.bar(x,y,color=colours,
        width=0.3,
        edgecolor = 'black',
        label = x)
plt.legend()
plt.grid()

# %%
## histogram -> distribution of data in bins(interval)
data = np.random.randn(1000)
plt.hist(data,bins=30)
plt.show()

# %%
## pychart -> distribution of data in slices

labels = ["a","b","c","d"]
sizes = [10,20,30,40]
explodes = (0,0,0,0.07)
plt.pie(sizes,labels=labels,autopct="%1.2f%%",shadow=True,explode=explodes)
plt.title('Pie - Chart')
plt.savefig('plot.png')
plt.show()
