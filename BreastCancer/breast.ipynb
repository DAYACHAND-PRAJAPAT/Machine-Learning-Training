# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('breast-cancer-wisconsin-data_data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
print(df.isna().sum())
df.duplicated().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.drop(["Unnamed: 32","id"],axis=1)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
cat_col = df.select_dtypes(include="O")
cat_col.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %%
num_col = df.select_dtypes(exclude="O")
num_col.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
cat_col['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
dt = {
    "B"  :  1,
"M"   : 0
}

cat_col["diagnosis"] = cat_col["diagnosis"].map(dt)
cat_col.head()
# Out:
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
fdf = pd.concat([cat_col,num_col],axis=1)
fdf.drop(['Unnamed: 32','id'],axis=1)
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            0        17.99         10.38          122.80     1001.0
# 1            0        20.57         17.77          132.90     1326.0
# 2            0        19.69         21.25          130.00     1203.0
# 3            0        11.42         20.38           77.58      386.1
# 4            0        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          0        21.56         22.39          142.00     1479.0
# 565          0        20.13         28.25          131.20     1261.0
# 566          0        16.60         28.08          108.30      858.1
# 567          0        20.60         29.33          140.10     1265.0
# 568          1         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
x = fdf.drop('diagnosis',axis=1)
y = fdf[["diagnosis"]]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(
    x,y,test_size=0.2,
    random_state=42
)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# to save the model
import joblib,pickle
joblib.dump(dt,"Breast_Cancer_Prediction.lb")

# %%
dt.score(x_test,y_test)
# Out:
# 0.9385964912280702

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
pred = dt.predict(x_test)
y_test["prediction"] = pred
y_test
# Out:
#      diagnosis  prediction
# 204          1           1
# 70           0           0
# 131          0           0
# 431          1           1
# 540          1           1
# ..         ...         ...
# 486          1           1
# 75           0           0
# 249          1           1
# 238          1           1
# 265          0           0
#
# [114 rows x 2 columns]

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
confusion_matrix(y_test["diagnosis"],y_test["prediction"])
# Out:
# array([[39,  4],
#        [ 3, 68]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test["diagnosis"],y_test["prediction"]),annot=True,fmt="d")
# Out:
# <Axes: >

# %%
print(classification_report(y_test["diagnosis"],y_test["prediction"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92        43
#            1       0.94      0.96      0.95        71
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.93      0.93       114
# weighted avg       0.94      0.94      0.94       114

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(40,20))
plot_tree(dt,filled=True,feature_names=x.columns)
class_name = ["<=50K",">50K"]
plt.show()
